# %%
import pandas as pd

# %%
df = pd.read_csv('prepd_dataset.csv')

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90994 entries, 0 to 90993
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   duration                     90994 non-null  int64
#  1   protocol_type                90994 non-null  object
#  2   service                      90994 non-null  object
#  3   flag                         90994 non-null  object
#  4   src_bytes                    90994 non-null  int64
#  5   dst_bytes                    90994 non-null  int64
#  6   land                         90994 non-null  int64
#  7   wrong_fragment               90994 non-null  int64
#  8   urgent                       90994 non-null  int64
#  9   hot                          90994 non-null  int64
#  10  num_failed_logins            90994 non-null  int64
#  11  logged_in                    90994 non-null  int64
#  12  num_compromised              90994 non-null  int64
#  13  root_shell                   90994 non-null  int64
#  14  su_attempted                 90994 non-null  int64
#  15  num_root                     90994 non-null  int64
#  16  num_file_creations           90994 non-null  int64
#  17  num_shells                   90994 non-null  int64
#  18  num_access_files             90994 non-null  int64
#  19  num_outbound_cmds            90994 non-null  int64
#  20  is_host_login                90994 non-null  int64
#  21  is_guest_login               90994 non-null  int64
#  22  count                        90994 non-null  int64
#  23  srv_count                    90994 non-null  int64
#  24  serror_rate                  90994 non-null  float64
#  25  diff_srv_rate                90994 non-null  float64
#  26  srv_diff_host_rate           90994 non-null  float64
#  27  dst_host_srv_count           90994 non-null  int64
#  28  dst_host_diff_srv_rate       90994 non-null  float64
#  29  dst_host_same_src_port_rate  90994 non-null  float64
#  30  dst_host_srv_diff_host_rate  90994 non-null  float64
#  31  dst_host_srv_rerror_rate     90994 non-null  float64
#  32  attack                       90994 non-null  object
#  33  level                        90994 non-null  int64
# dtypes: float64(7), int64(23), object(4)
# memory usage: 23.6+ MB

# %%
NUMERIC_FEATURES = nums = df.select_dtypes(exclude=["object"]).columns

# %%
df['root_shell'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
NUMERIC_FEATURES
# Out:
# Index(['duration', 'src_bytes', 'dst_bytes', 'land', 'wrong_fragment',
#        'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised',
#        'root_shell', 'su_attempted', 'num_root', 'num_file_creations',
#        'num_shells', 'num_access_files', 'num_outbound_cmds', 'is_host_login',
#        'is_guest_login', 'count', 'srv_count', 'serror_rate', 'diff_srv_rate',
#        'srv_diff_host_rate', 'dst_host_srv_count', 'dst_host_diff_srv_rate',
#        'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate',
#        'dst_host_srv_rerror_rate', 'level'],
#       dtype='object')

# %%
NUMERIC_FEATURES = ['duration', 'src_bytes', 'dst_bytes', 'wrong_fragment',
       'urgent', 'hot', 'num_failed_logins', 'num_compromised',
        'num_root', 'num_file_creations',
       'num_shells', 'num_access_files', 'num_outbound_cmds',
       'count', 'srv_count', 'serror_rate', 'diff_srv_rate',
       'srv_diff_host_rate', 'dst_host_srv_count', 'dst_host_diff_srv_rate',
       'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate',
       'dst_host_srv_rerror_rate']

# %%
CAT_FEATURES = nums = df.select_dtypes(exclude=["number"]).columns

# %%
CAT_FEATURES = [
    'logged_in',
    'protocol_type',
    'service',
    'flag',
    'root_shell',
    'su_attempted',
    'is_host_login',
    'is_guest_login'
]

# %%
for col in CAT_FEATURES:
    if x_train[col].apply(lambda x: isinstance(x, (int))).any():
        print(f"⚠️ Column '{col}' contains non-scalar values!")
# Out:
# ⚠️ Column 'logged_in' contains non-scalar values!
# ⚠️ Column 'is_host_login' contains non-scalar values!
# ⚠️ Column 'is_guest_login' contains non-scalar values!

# %%
len(NUMERIC_FEATURES) + len(CAT_FEATURES)
# Out:
# 31

# %%
df['attack'] = df['attack'].apply(lambda x: 0 if x == 'normal' else 1)

# %%
df['attack'] = df['attack'].astype('str')
df['logged_in'] = df['logged_in'].astype('str')
df['is_host_login'] = df['is_host_login'].astype('str')
df['is_guest_login'] = df['is_guest_login'].astype('str')

# %%
df.head()
# Out:
#    duration protocol_type  service flag  src_bytes  dst_bytes  land  \
# 0         0           udp    other   SF        146          0     0
# 1         0           tcp  private   S0          0          0     0
# 2         0           tcp     http   SF        199        420     0
# 3         0           tcp  private  REJ          0          0     0
# 4         0           tcp  private   S0          0          0     0
#
#    wrong_fragment  urgent  hot  ...  serror_rate diff_srv_rate  \
# 0               0       0    0  ...          0.0          0.15
# 1               0       0    0  ...          1.0          0.07
# 2               0       0    0  ...          0.0          0.00
# 3               0       0    0  ...          0.0          0.06
# 4               0       0    0  ...          1.0          0.06
#
#    srv_diff_host_rate  dst_host_srv_count  dst_host_diff_srv_rate  \
# 0                0.00                   1                    0.60
# 1                0.00                  26                    0.05
# 2                0.09                 255                    0.00
# 3                0.00                  19                    0.07
# 4                0.00                   9                    0.05
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.88                          0.0
# 1                         0.00                          0.0
# 2                         0.00                          0.0
# 3                         0.00                          0.0
# 4                         0.00                          0.0
#
#    dst_host_srv_rerror_rate  attack  level
# 0                       0.0       0     15
# 1                       0.0       1     19
# 2                       0.0       0     21
# 3                       1.0       1     21
# 4                       0.0       1     21
#
# [5 rows x 34 columns]

# %%
from sklearn.model_selection import train_test_split

train_features = NUMERIC_FEATURES + CAT_FEATURES
X = df[train_features]
y = df['attack']

# %%
X.shape
# Out:
# (90994, 31)

# %%
y.shape
# Out:
# (90994,)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, random_state=32)

# %%
x_train.shape
# Out:
# (68245, 31)

# %%
x_train.columns
# Out:
# Index(['duration', 'src_bytes', 'dst_bytes', 'wrong_fragment', 'urgent', 'hot',
#        'num_failed_logins', 'num_compromised', 'num_root',
#        'num_file_creations', 'num_shells', 'num_access_files',
#        'num_outbound_cmds', 'count', 'srv_count', 'serror_rate',
#        'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_srv_count',
#        'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
#        'dst_host_srv_diff_host_rate', 'dst_host_srv_rerror_rate', 'logged_in',
#        'protocol_type', 'service', 'flag', 'root_shell', 'su_attempted',
#        'is_host_login', 'is_guest_login'],
#       dtype='object')

# %%
y_train.shape
# Out:
# (68245,)

# %%
y_test.shape
# Out:
# (22749,)

# %%
x_test.shape
# Out:
# (22749, 31)

# %%
import torch

from pytorch_tabular import TabularModel
from pytorch_tabular.models import TabTransformerConfig
from pytorch_tabular.config import DataConfig, OptimizerConfig, TrainerConfig

# %%
import torch
print(f"CUDA Available: {torch.cuda.is_available()}")
print(f"GPU Name: {torch.cuda.get_device_name(0)}")
# Out:
# CUDA Available: True
# GPU Name: NVIDIA GeForce GTX 1050

# %%
data_config = DataConfig(
    target=["attack"],
    continuous_cols=NUMERIC_FEATURES,  # Numerical features
    categorical_cols=CAT_FEATURES,  # Categorical features
)

trainer_config = TrainerConfig(
    accelerator="gpu",
    devices=-1,
    precision=16,
    auto_lr_find=True,
    batch_size=32,
    max_epochs=4,
)

optimizer_config = OptimizerConfig()

model_config = TabTransformerConfig(
    task="classification",
    input_embed_dim=32,  # Embedding dimension
    num_heads=4,  # Number of attention heads
    num_attn_blocks=6,  # Number of transformer blocks
    learning_rate=1e-3,
)


tabular_model = TabularModel(
    data_config=data_config,
    model_config=model_config,
    optimizer_config=optimizer_config,
    trainer_config=trainer_config,
)

# trainer = x_train.join(y_train)
trainer = pd.concat([x_train, y_train.rename("attack")], axis=1)
# trainer.shape
tabular_model.fit(train=trainer)
# Out:
# 2025-04-30 00:35:42,667 - {pytorch_tabular.tabular_model:146} - INFO - Experiment Tracking is turned off
# Seed set to 42
# 2025-04-30 00:35:42,786 - {pytorch_tabular.tabular_model:548} - INFO - Preparing the DataLoaders
# 2025-04-30 00:35:43,141 - {pytorch_tabular.tabular_datamodule:522} - INFO - Setting up the datamodule for
# classification task
# 2025-04-30 00:35:44,433 - {pytorch_tabular.tabular_model:599} - INFO - Preparing the Model: TabTransformerModel
# 2025-04-30 00:35:44,722 - {pytorch_tabular.tabular_model:342} - INFO - Preparing the Trainer
# C:\Users\Rahul Siloniya\AppData\Local\Programs\Python\Python311\Lib\site-packages\lightning_fabric\connector.py:571: `precision=16` is supported for historical reasons but its usage is discouraged. Please set your precision to 16-mixed instead!
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# 2025-04-30 00:35:44,980 - {pytorch_tabular.tabular_model:656} - INFO - Auto LR Find Started
# C:\Users\Rahul Siloniya\AppData\Local\Programs\Python\Python311\Lib\site-packages\pytorch_lightning\callbacks\model_checkpoint.py:654: Checkpoint directory D:\projects\FinalYearProject\saved_models exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# C:\Users\Rahul Siloniya\AppData\Local\Programs\Python\Python311\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:424: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# C:\Users\Rahul Siloniya\AppData\Local\Programs\Python\Python311\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:424: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# Finding best initial lr:   0%|          | 0/100 [00:00<?, ?it/s]
# C:\Users\Rahul Siloniya\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\optim\lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# `Trainer.fit` stopped: `max_steps=100` reached.
# Learning rate set to 0.0002089296130854041
# Restoring states from the checkpoint path at D:\projects\FinalYearProject\.lr_find_6dc46396-5120-4322-bd9d-3966c9aa797e.ckpt
# Restored all states from the checkpoint at D:\projects\FinalYearProject\.lr_find_6dc46396-5120-4322-bd9d-3966c9aa797e.ckpt
# 2025-04-30 00:36:18,749 - {pytorch_tabular.tabular_model:669} - INFO - Suggested LR: 0.0002089296130854041. For
# plot and detailed analysis, use `find_learning_rate` method.
# 2025-04-30 00:36:18,772 - {pytorch_tabular.tabular_model:678} - INFO - Training Started
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name             ┃ Type                   ┃ Params ┃ Mode  ┃
# ┡━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ 0 │ _backbone        │ TabTransformerBackbone │  173 K │ train │
# │ 1 │ _embedding_layer │ Embedding2dLayer       │  3.2 K │ train │
# │ 2 │ _head            │ LinearHead             │    560 │ train │
# │ 3 │ loss             │ CrossEntropyLoss       │      0 │ train │
# └───┴──────────────────┴────────────────────────┴────────┴───────┘
# Trainable params: 176 K
# Non-trainable params: 0
# Total params: 176 K
# Total estimated model params size (MB): 0
# Modules in train mode: 135
# Modules in eval mode: 0
# Output()
# `Trainer.fit` stopped: `max_epochs=4` reached.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 2025-04-30 00:45:00,342 - {pytorch_tabular.tabular_model:689} - INFO - Training the model completed
# 2025-04-30 00:45:00,344 - {pytorch_tabular.tabular_model:1529} - INFO - Loading the best model

# %%
preds = tabular_model.predict(x_test)

# %%
preds['attack_prediction'].dtype
# Out:
# dtype('O')

# %%
preds.head()
# Out:
#        attack_0_probability  attack_1_probability attack_prediction
# 22974              0.000036              0.999964                 1
# 6286               0.000072              0.999928                 1
# 45792              0.000076              0.999924                 1
# 61070              0.000131              0.999869                 1
# 44201              0.000017              0.999983                 1

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, preds['attack_prediction'])
print(f"Accuracy: {accuracy:.4f}")
print(f"Accuracy percentage (x100): {accuracy * 100:.4f}")
# Out:
# Accuracy: 0.9730
# Accuracy percentage (x100): 97.2966

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# Assuming `y_test` contains the true labels for `x_test`
y_true = y_test.values.ravel()  # Convert to 1D array if needed
y_pred = preds["attack_prediction"].values  # Extract predicted labels

# Compute performance metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average="weighted")
recall = recall_score(y_true, y_pred, average="weighted")
f1 = f1_score(y_true, y_pred, average="weighted")

# Print metrics
print(f"Accuracy: {accuracy:.6f}")
print(f"Precision: {precision:.6f}")
print(f"Recall: {recall:.6f}")
print(f"F1 Score: {f1:.6f}")

# Display classification report
print("\nClassification Report:\n", classification_report(y_true, y_pred))

# Display confusion matrix
print("\nConfusion Matrix:\n", confusion_matrix(y_true, y_pred))
# Out:
# Accuracy: 0.972966
# Precision: 0.972960
# Recall: 0.972966
# F1 Score: 0.972933
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      8995
#            1       0.97      0.98      0.98     13754
#
#     accuracy                           0.97     22749
#    macro avg       0.97      0.97      0.97     22749
# weighted avg       0.97      0.97      0.97     22749
#
#
# Confusion Matrix:
#  [[ 8626   369]
#  [  246 13508]]

# %%
tabular_model.summary()
# Out:
#     | Name                                                                | Type                    | Params | Mode
# -------------------------------------------------------------------------------------------------------------------------
# 0   | _backbone                                                           | TabTransformerBackbone  | 173 K  | eval
# 1   | _backbone.transformer_blocks                                        | Sequential              | 172 K  | eval
# 2   | _backbone.transformer_blocks.mha_block_0                            | TransformerEncoderBlock | 28.8 K | eval
# 3   | _backbone.transformer_blocks.mha_block_0.mha                        | MultiHeadedAttention    | 16.4 K | eval
# 4   | _backbone.transformer_blocks.mha_block_0.mha.to_qkv                 | Linear                  | 12.3 K | eval
# 5   | _backbone.transformer_blocks.mha_block_0.mha.to_out                 | Linear                  | 4.1 K  | eval
# 6   | _backbone.transformer_blocks.mha_block_0.mha.dropout                | Dropout                 | 0      | eval
# 7   | _backbone.transformer_blocks.mha_block_0.pos_wise_ff                | GEGLU                   | 12.3 K | eval
# 8   | _backbone.transformer_blocks.mha_block_0.pos_wise_ff.ffn            | PositionWiseFeedForward | 12.3 K | eval
# 9   | _backbone.transformer_blocks.mha_block_0.pos_wise_ff.ffn.layer1     | Linear                  | 4.1 K  | eval
# 10  | _backbone.transformer_blocks.mha_block_0.pos_wise_ff.ffn.layer2     | Linear                  | 4.1 K  | eval
# 11  | _backbone.transformer_blocks.mha_block_0.pos_wise_ff.ffn.dropout    | Dropout                 | 0      | eval
# 12  | _backbone.transformer_blocks.mha_block_0.pos_wise_ff.ffn.activation | GELU                    | 0      | eval
# 13  | _backbone.transformer_blocks.mha_block_0.pos_wise_ff.ffn.linear_v   | Linear                  | 4.1 K  | eval
# 14  | _backbone.transformer_blocks.mha_block_0.attn_add_norm              | AddNorm                 | 64     | eval
# 15  | _backbone.transformer_blocks.mha_block_0.attn_add_norm.dropout      | Dropout                 | 0      | eval
# 16  | _backbone.transformer_blocks.mha_block_0.attn_add_norm.ln           | LayerNorm               | 64     | eval
# 17  | _backbone.transformer_blocks.mha_block_0.ff_add_norm                | AddNorm                 | 64     | eval
# 18  | _backbone.transformer_blocks.mha_block_0.ff_add_norm.dropout        | Dropout                 | 0      | eval
# 19  | _backbone.transformer_blocks.mha_block_0.ff_add_norm.ln             | LayerNorm               | 64     | eval
# 20  | _backbone.transformer_blocks.mha_block_1                            | TransformerEncoderBlock | 28.8 K | eval
# 21  | _backbone.transformer_blocks.mha_block_1.mha                        | MultiHeadedAttention    | 16.4 K | eval
# 22  | _backbone.transformer_blocks.mha_block_1.mha.to_qkv                 | Linear                  | 12.3 K | eval
# 23  | _backbone.transformer_blocks.mha_block_1.mha.to_out                 | Linear                  | 4.1 K  | eval
# 24  | _backbone.transformer_blocks.mha_block_1.mha.dropout                | Dropout                 | 0      | eval
# 25  | _backbone.transformer_blocks.mha_block_1.pos_wise_ff                | GEGLU                   | 12.3 K | eval
# 26  | _backbone.transformer_blocks.mha_block_1.pos_wise_ff.ffn            | PositionWiseFeedForward | 12.3 K | eval
# 27  | _backbone.transformer_blocks.mha_block_1.pos_wise_ff.ffn.layer1     | Linear                  | 4.1 K  | eval
# 28  | _backbone.transformer_blocks.mha_block_1.pos_wise_ff.ffn.layer2     | Linear                  | 4.1 K  | eval
# 29  | _backbone.transformer_blocks.mha_block_1.pos_wise_ff.ffn.dropout    | Dropout                 | 0      | eval
# 30  | _backbone.transformer_blocks.mha_block_1.pos_wise_ff.ffn.activation | GELU                    | 0      | eval
# 31  | _backbone.transformer_blocks.mha_block_1.pos_wise_ff.ffn.linear_v   | Linear                  | 4.1 K  | eval
# 32  | _backbone.transformer_blocks.mha_block_1.attn_add_norm              | AddNorm                 | 64     | eval
# 33  | _backbone.transformer_blocks.mha_block_1.attn_add_norm.dropout      | Dropout                 | 0      | eval
# 34  | _backbone.transformer_blocks.mha_block_1.attn_add_norm.ln           | LayerNorm               | 64     | eval
# 35  | _backbone.transformer_blocks.mha_block_1.ff_add_norm                | AddNorm                 | 64     | eval
# 36  | _backbone.transformer_blocks.mha_block_1.ff_add_norm.dropout        | Dropout                 | 0      | eval
# 37  | _backbone.transformer_blocks.mha_block_1.ff_add_norm.ln             | LayerNorm               | 64     | eval
# 38  | _backbone.transformer_blocks.mha_block_2                            | TransformerEncoderBlock | 28.8 K | eval
# 39  | _backbone.transformer_blocks.mha_block_2.mha                        | MultiHeadedAttention    | 16.4 K | eval
# 40  | _backbone.transformer_blocks.mha_block_2.mha.to_qkv                 | Linear                  | 12.3 K | eval
# 41  | _backbone.transformer_blocks.mha_block_2.mha.to_out                 | Linear                  | 4.1 K  | eval
# 42  | _backbone.transformer_blocks.mha_block_2.mha.dropout                | Dropout                 | 0      | eval
# 43  | _backbone.transformer_blocks.mha_block_2.pos_wise_ff                | GEGLU                   | 12.3 K | eval
# 44  | _backbone.transformer_blocks.mha_block_2.pos_wise_ff.ffn            | PositionWiseFeedForward | 12.3 K | eval
# 45  | _backbone.transformer_blocks.mha_block_2.pos_wise_ff.ffn.layer1     | Linear                  | 4.1 K  | eval
# 46  | _backbone.transformer_blocks.mha_block_2.pos_wise_ff.ffn.layer2     | Linear                  | 4.1 K  | eval
# 47  | _backbone.transformer_blocks.mha_block_2.pos_wise_ff.ffn.dropout    | Dropout                 | 0      | eval
# 48  | _backbone.transformer_blocks.mha_block_2.pos_wise_ff.ffn.activation | GELU                    | 0      | eval
# 49  | _backbone.transformer_blocks.mha_block_2.pos_wise_ff.ffn.linear_v   | Linear                  | 4.1 K  | eval
# 50  | _backbone.transformer_blocks.mha_block_2.attn_add_norm              | AddNorm                 | 64     | eval
# 51  | _backbone.transformer_blocks.mha_block_2.attn_add_norm.dropout      | Dropout                 | 0      | eval
# 52  | _backbone.transformer_blocks.mha_block_2.attn_add_norm.ln           | LayerNorm               | 64     | eval
# 53  | _backbone.transformer_blocks.mha_block_2.ff_add_norm                | AddNorm                 | 64     | eval
# 54  | _backbone.transformer_blocks.mha_block_2.ff_add_norm.dropout        | Dropout                 | 0      | eval
# 55  | _backbone.transformer_blocks.mha_block_2.ff_add_norm.ln             | LayerNorm               | 64     | eval
# 56  | _backbone.transformer_blocks.mha_block_3                            | TransformerEncoderBlock | 28.8 K | eval
# 57  | _backbone.transformer_blocks.mha_block_3.mha                        | MultiHeadedAttention    | 16.4 K | eval
# 58  | _backbone.transformer_blocks.mha_block_3.mha.to_qkv                 | Linear                  | 12.3 K | eval
# 59  | _backbone.transformer_blocks.mha_block_3.mha.to_out                 | Linear                  | 4.1 K  | eval
# 60  | _backbone.transformer_blocks.mha_block_3.mha.dropout                | Dropout                 | 0      | eval
# 61  | _backbone.transformer_blocks.mha_block_3.pos_wise_ff                | GEGLU                   | 12.3 K | eval
# 62  | _backbone.transformer_blocks.mha_block_3.pos_wise_ff.ffn            | PositionWiseFeedForward | 12.3 K | eval
# 63  | _backbone.transformer_blocks.mha_block_3.pos_wise_ff.ffn.layer1     | Linear                  | 4.1 K  | eval
# 64  | _backbone.transformer_blocks.mha_block_3.pos_wise_ff.ffn.layer2     | Linear                  | 4.1 K  | eval
# 65  | _backbone.transformer_blocks.mha_block_3.pos_wise_ff.ffn.dropout    | Dropout                 | 0      | eval
# 66  | _backbone.transformer_blocks.mha_block_3.pos_wise_ff.ffn.activation | GELU                    | 0      | eval
# 67  | _backbone.transformer_blocks.mha_block_3.pos_wise_ff.ffn.linear_v   | Linear                  | 4.1 K  | eval
# 68  | _backbone.transformer_blocks.mha_block_3.attn_add_norm              | AddNorm                 | 64     | eval
# 69  | _backbone.transformer_blocks.mha_block_3.attn_add_norm.dropout      | Dropout                 | 0      | eval
# 70  | _backbone.transformer_blocks.mha_block_3.attn_add_norm.ln           | LayerNorm               | 64     | eval
# 71  | _backbone.transformer_blocks.mha_block_3.ff_add_norm                | AddNorm                 | 64     | eval
# 72  | _backbone.transformer_blocks.mha_block_3.ff_add_norm.dropout        | Dropout                 | 0      | eval
# 73  | _backbone.transformer_blocks.mha_block_3.ff_add_norm.ln             | LayerNorm               | 64     | eval
# 74  | _backbone.transformer_blocks.mha_block_4                            | TransformerEncoderBlock | 28.8 K | eval
# 75  | _backbone.transformer_blocks.mha_block_4.mha                        | MultiHeadedAttention    | 16.4 K | eval
# 76  | _backbone.transformer_blocks.mha_block_4.mha.to_qkv                 | Linear                  | 12.3 K | eval
# 77  | _backbone.transformer_blocks.mha_block_4.mha.to_out                 | Linear                  | 4.1 K  | eval
# 78  | _backbone.transformer_blocks.mha_block_4.mha.dropout                | Dropout                 | 0      | eval
# 79  | _backbone.transformer_blocks.mha_block_4.pos_wise_ff                | GEGLU                   | 12.3 K | eval
# 80  | _backbone.transformer_blocks.mha_block_4.pos_wise_ff.ffn            | PositionWiseFeedForward | 12.3 K | eval
# 81  | _backbone.transformer_blocks.mha_block_4.pos_wise_ff.ffn.layer1     | Linear                  | 4.1 K  | eval
# 82  | _backbone.transformer_blocks.mha_block_4.pos_wise_ff.ffn.layer2     | Linear                  | 4.1 K  | eval
# 83  | _backbone.transformer_blocks.mha_block_4.pos_wise_ff.ffn.dropout    | Dropout                 | 0      | eval
# 84  | _backbone.transformer_blocks.mha_block_4.pos_wise_ff.ffn.activation | GELU                    | 0      | eval
# 85  | _backbone.transformer_blocks.mha_block_4.pos_wise_ff.ffn.linear_v   | Linear                  | 4.1 K  | eval
# 86  | _backbone.transformer_blocks.mha_block_4.attn_add_norm              | AddNorm                 | 64     | eval
# 87  | _backbone.transformer_blocks.mha_block_4.attn_add_norm.dropout      | Dropout                 | 0      | eval
# 88  | _backbone.transformer_blocks.mha_block_4.attn_add_norm.ln           | LayerNorm               | 64     | eval
# 89  | _backbone.transformer_blocks.mha_block_4.ff_add_norm                | AddNorm                 | 64     | eval
# 90  | _backbone.transformer_blocks.mha_block_4.ff_add_norm.dropout        | Dropout                 | 0      | eval
# 91  | _backbone.transformer_blocks.mha_block_4.ff_add_norm.ln             | LayerNorm               | 64     | eval
# 92  | _backbone.transformer_blocks.mha_block_5                            | TransformerEncoderBlock | 28.8 K | eval
# 93  | _backbone.transformer_blocks.mha_block_5.mha                        | MultiHeadedAttention    | 16.4 K | eval
# 94  | _backbone.transformer_blocks.mha_block_5.mha.to_qkv                 | Linear                  | 12.3 K | eval
# 95  | _backbone.transformer_blocks.mha_block_5.mha.to_out                 | Linear                  | 4.1 K  | eval
# 96  | _backbone.transformer_blocks.mha_block_5.mha.dropout                | Dropout                 | 0      | eval
# 97  | _backbone.transformer_blocks.mha_block_5.pos_wise_ff                | GEGLU                   | 12.3 K | eval
# 98  | _backbone.transformer_blocks.mha_block_5.pos_wise_ff.ffn            | PositionWiseFeedForward | 12.3 K | eval
# 99  | _backbone.transformer_blocks.mha_block_5.pos_wise_ff.ffn.layer1     | Linear                  | 4.1 K  | eval
# 100 | _backbone.transformer_blocks.mha_block_5.pos_wise_ff.ffn.layer2     | Linear                  | 4.1 K  | eval
# 101 | _backbone.transformer_blocks.mha_block_5.pos_wise_ff.ffn.dropout    | Dropout                 | 0      | eval
# 102 | _backbone.transformer_blocks.mha_block_5.pos_wise_ff.ffn.activation | GELU                    | 0      | eval
# 103 | _backbone.transformer_blocks.mha_block_5.pos_wise_ff.ffn.linear_v   | Linear                  | 4.1 K  | eval
# 104 | _backbone.transformer_blocks.mha_block_5.attn_add_norm              | AddNorm                 | 64     | eval
# 105 | _backbone.transformer_blocks.mha_block_5.attn_add_norm.dropout      | Dropout                 | 0      | eval
# 106 | _backbone.transformer_blocks.mha_block_5.attn_add_norm.ln           | LayerNorm               | 64     | eval
# 107 | _backbone.transformer_blocks.mha_block_5.ff_add_norm                | AddNorm                 | 64     | eval
# 108 | _backbone.transformer_blocks.mha_block_5.ff_add_norm.dropout        | Dropout                 | 0      | eval
# 109 | _backbone.transformer_blocks.mha_block_5.ff_add_norm.ln             | LayerNorm               | 64     | eval
# 110 | _backbone.normalizing_batch_norm                                    | BatchNorm1d             | 46     | eval
# 111 | _backbone.normalizing_batch_norm.bn                                 | BatchNorm1d             | 46     | eval
# 112 | _embedding_layer                                                    | Embedding2dLayer        | 3.2 K  | eval
# 113 | _embedding_layer.cat_embedding_layers                               | ModuleList              | 3.2 K  | eval
# 114 | _embedding_layer.cat_embedding_layers.0                             | SharedEmbeddings        | 104    | eval
# 115 | _embedding_layer.cat_embedding_layers.0.embed                       | Embedding               | 96     | eval
# 116 | _embedding_layer.cat_embedding_layers.1                             | SharedEmbeddings        | 136    | eval
# 117 | _embedding_layer.cat_embedding_layers.1.embed                       | Embedding               | 128    | eval
# 118 | _embedding_layer.cat_embedding_layers.2                             | SharedEmbeddings        | 2.2 K  | eval
# 119 | _embedding_layer.cat_embedding_layers.2.embed                       | Embedding               | 2.2 K  | eval
# 120 | _embedding_layer.cat_embedding_layers.3                             | SharedEmbeddings        | 392    | eval
# 121 | _embedding_layer.cat_embedding_layers.3.embed                       | Embedding               | 384    | eval
# 122 | _embedding_layer.cat_embedding_layers.4                             | SharedEmbeddings        | 104    | eval
# 123 | _embedding_layer.cat_embedding_layers.4.embed                       | Embedding               | 96     | eval
# 124 | _embedding_layer.cat_embedding_layers.5                             | SharedEmbeddings        | 72     | eval
# 125 | _embedding_layer.cat_embedding_layers.5.embed                       | Embedding               | 64     | eval
# 126 | _embedding_layer.cat_embedding_layers.6                             | SharedEmbeddings        | 72     | eval
# 127 | _embedding_layer.cat_embedding_layers.6.embed                       | Embedding               | 64     | eval
# 128 | _embedding_layer.cat_embedding_layers.7                             | SharedEmbeddings        | 104    | eval
# 129 | _embedding_layer.cat_embedding_layers.7.embed                       | Embedding               | 96     | eval
# 130 | _embedding_layer.cont_embedding_layer                               | Embedding               | 0      | eval
# 131 | _head                                                               | LinearHead              | 560    | eval
# 132 | _head.layers                                                        | Sequential              | 560    | eval
# 133 | _head.layers.0                                                      | Linear                  | 560    | eval
# 134 | loss                                                                | CrossEntropyLoss        | 0      | eval
# -------------------------------------------------------------------------------------------------------------------------
# 176 K     Trainable params
# 0         Non-trainable params
# 176 K     Total params
# 0.707     Total estimated model params size (MB)
# 0         Modules in train mode
# 135       Modules in eval mode
